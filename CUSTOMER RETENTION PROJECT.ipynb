# %% [markdown]
# # CUSTOMER RETENTION

# %%
# Import libraries and datasets

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
  
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import mean_absolute_percentage_error as mape
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
  
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_excel("C:\\Users\\Dell\\Desktop\\customer_retention_dataset.xlsx")

# %%
df
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %%
df.shape
# Out:
# (269, 71)

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
df.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
df.tail()
# Out:
#     1Gender of respondent 2 How old are you?   \
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 264                                 Solan
# 265                             Ghaziabad
# 266                            Bangalore
# 267                                 Solan
# 268                             Ghaziabad
#
#      4 What is the Pin Code of where you shop online from?  \
# 264                                             173212
# 265                                             201008
# 266                                             560010
# 267                                             173229
# 268                                             201009
#
#     5 Since How Long You are Shopping Online ?  \
# ...

# %%
df.sample()
# Out:
#    1Gender of respondent 2 How old are you?   \
# 53                Female         41-50 yaers
#
#    3 Which city do you shop online from?  \
# 53                         Greater Noida
#
#     4 What is the Pin Code of where you shop online from?  \
# 53                                             201312
#
#    5 Since How Long You are Shopping Online ?  \
# 53                              Above 4 years
#
#    6 How many times you have made an online purchase in the past 1 year?  \
# 53                                 41 times and above
#
#    7 How do you access the internet while shopping on-line?  \
# 53                                    Mobile internet
#
#    8 Which device do you use to access the online shopping?  \
# 53                                            Desktop
#
#    9 What is the screen size of your mobile device?\t\t\t\t\t\t                                          \
# 53                                             Others
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %%
df.describe()
# Out:
#        4 What is the Pin Code of where you shop online from?
# count                                         269.000000
# mean                                       220465.747212
# std                                        140524.341051
# min                                        110008.000000
# 25%                                        122018.000000
# 50%                                        201303.000000
# 75%                                        201310.000000
# max                                        560037.000000

# %%
codesheet=pd.read_excel("C:\\Users\\Dell\\Desktop\\customer_retention_dataset.xlsx",sheet_name="codedsheet")

# %%
codesheet
# Out:
#      1Gender of respondent  2 How old are you?   \
# 0                        0                    3
# 1                        1                    2
# 2                        1                    2
# 3                        0                    2
# 4                        1                    2
# ..                     ...                  ...
# 264                      1                    2
# 265                      1                    3
# 266                      1                    4
# 267                      1                    1
# 268                      1                    4
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# ...

# %%
codesheet.shape
# Out:
# (269, 71)

# %%
codesheet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    int64
# ...

# %%
codesheet.count()
# Out:
# 1Gender of respondent                                                   269
# 2 How old are you?                                                      269
# 3 Which city do you shop online from?                                   269
# 4 What is the Pin Code of where you shop online from?                   269
# 5 Since How Long You are Shopping Online ?                              269
#                                                                        ...
# Longer delivery period                                                  269
# Change in website/Application design                                    269
# Frequent disruption when moving from one page to another                269
# Website is as efficient as before                                       269
# Which of the Indian online retailer would you recommend to a friend?    269
# Length: 71, dtype: int64

# %%
codesheet.corr()
# Out:
#                                                     1Gender of respondent  \
# 1Gender of respondent                                            1.000000
# 2 How old are you?                                              -0.034449
# 4 What is the Pin Code of where you shop online...               0.260696
# 5 Since How Long You are Shopping Online ?                      -0.046005
# 6 How many times you have made an online purcha...               0.076121
# 7 How do you access the internet while shopping...              -0.200974
# 8 Which device do you use to access the online ...              -0.241847
# 9 What is the screen size of your mobile device...              -0.058760
# 10 What is the operating system (OS) of your de...              -0.038207
# 11 What browser do you run on your device to ac...              -0.116712
# 12 Which channel did you follow to arrive at yo...              -0.166694
# 13 After first visit, how do you reach the onli...               0.104118
# ...

# %%
codesheet.describe()
# Out:
#        1Gender of respondent  2 How old are you?   \
# count             269.000000           269.000000
# mean                0.669145             2.959108
# std                 0.471398             1.066012
# min                 0.000000             1.000000
# 25%                 0.000000             2.000000
# 50%                 1.000000             3.000000
# 75%                 1.000000             4.000000
# max                 1.000000             5.000000
#
#        4 What is the Pin Code of where you shop online from?  \
# count                                         269.000000
# mean                                       220465.747212
# std                                        140524.341051
# min                                        110008.000000
# 25%                                        122018.000000
# 50%                                        201303.000000
# 75%                                        201310.000000
# ...

# %%
df_modified=codesheet.copy()
df_modified
# Out:
#      1Gender of respondent  2 How old are you?   \
# 0                        0                    3
# 1                        1                    2
# 2                        1                    2
# 3                        0                    2
# 4                        1                    2
# ..                     ...                  ...
# 264                      1                    2
# 265                      1                    3
# 266                      1                    4
# 267                      1                    1
# 268                      1                    4
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# ...

# %%
df_modified.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
columns_to_drop=['3 Which city do you shop online from?', '4 What is the Pin Code of where you shop online from?']

# %%
df_modified=df_modified.drop(columns=columns_to_drop)
df_modified
# Out:
#      1Gender of respondent  2 How old are you?   \
# 0                        0                    3
# 1                        1                    2
# 2                        1                    2
# 3                        0                    2
# 4                        1                    2
# ..                     ...                  ...
# 264                      1                    2
# 265                      1                    3
# 266                      1                    4
# 267                      1                    1
# 268                      1                    4
#
#      5 Since How Long You are Shopping Online ?  \
# 0                                             5
# 1                                             5
# 2                                             4
# 3                                             4
# 4                                             3
# ..                                          ...
# ...

# %%
id_vars=list(df_modified.columns)[:10]
value_vars=list(df_modified.columns)[10:]

# %%
df_melted=df_modified.melt(id_vars=id_vars, value_vars=value_vars)
df_melted
# Out:
#        1Gender of respondent  2 How old are you?   \
# 0                          0                    3
# 1                          1                    2
# 2                          1                    2
# 3                          0                    2
# 4                          1                    2
# ...                      ...                  ...
# 15866                      1                    2
# 15867                      1                    3
# 15868                      1                    4
# 15869                      1                    1
# 15870                      1                    4
#
#        5 Since How Long You are Shopping Online ?  \
# 0                                               5
# 1                                               5
# 2                                               4
# 3                                               4
# 4                                               3
# ...                                           ...
# ...

# %%
# EDA and Data visulisation
df_melted.isnull().sum()
# Out:
# 1Gender of respondent                                                                                                                                             0
# 2 How old are you?                                                                                                                                                0
# 5 Since How Long You are Shopping Online ?                                                                                                                        0
# 6 How many times you have made an online purchase in the past 1 year?                                                                                             0
# 7 How do you access the internet while shopping on-line?                                                                                                          0
# 8 Which device do you use to access the online shopping?                                                                                                          0
# ...

# %%
df_melted.hist(bins=20, figsize=(10, 10))
plt.show()

# %%
df_melted.corr()
# Out:
#                                                     1Gender of respondent  \
# 1Gender of respondent                                            1.000000
# 2 How old are you?                                              -0.034449
# 5 Since How Long You are Shopping Online ?                      -0.046005
# 6 How many times you have made an online purcha...               0.076121
# 7 How do you access the internet while shopping...              -0.200974
# 8 Which device do you use to access the online ...              -0.241847
# 9 What is the screen size of your mobile device...              -0.058760
# 10 What is the operating system (OS) of your de...              -0.038207
# 11 What browser do you run on your device to ac...              -0.116712
# 12 Which channel did you follow to arrive at yo...              -0.166694
#
#                                                     2 How old are you?   \
# 1Gender of respondent                                         -0.034449
# ...

# %%
plt.figure(figsize=(20, 10))
sb.heatmap(df_melted.corr(),annot=True,linewidth=0.5,linecolor='black', fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
df_melted.describe()
# Out:
#        1Gender of respondent  2 How old are you?   \
# count           15871.000000         15871.000000
# mean                0.669145             2.959108
# std                 0.470536             1.064062
# min                 0.000000             1.000000
# 25%                 0.000000             2.000000
# 50%                 1.000000             3.000000
# 75%                 1.000000             4.000000
# max                 1.000000             5.000000
#
#        5 Since How Long You are Shopping Online ?  \
# count                                15871.000000
# mean                                     3.524164
# std                                      1.433959
# min                                      1.000000
# 25%                                      3.000000
# 50%                                      4.000000
# 75%                                      5.000000
# max                                      5.000000
#
# ...

# %%
plt.figure(figsize=(15,8))
sb.heatmap(round(df_melted.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt='f')
plt.xticks(fontsize=15)
plt.xticks(fontsize=12)
plt.title('Variables Summary')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %%
df.skew()
# Out:
# 4 What is the Pin Code of where you shop online from?    1.748322
# dtype: float64

# %%
sb.displot(df['4 What is the Pin Code of where you shop online from?'])
